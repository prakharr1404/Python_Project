# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\prakh\OneDrive\Desktop\Python\data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#             job_title_short                                     job_title  \
# 172872    Software Engineer                    Research Software Engineer
# 129113        Data Engineer                                 Data Engineer
# 168918       Data Scientist                                Data Scientist
# 777120       Data Scientist                         Data Bricks Developer
# 281295    Software Engineer                      Project Quality Engineer
# 654723  Senior Data Analyst                        Senior Digital Analyst
# 24589          Data Analyst                                  Data Analyst
# 338410        Data Engineer                                 Data Engineer
# 299300       Data Scientist                      Data Scientist-MLOps AWS
# 765415       Data Scientist  Data Scientist, Pricing & Revenue Management
#
#                       job_location         job_via        job_schedule_type  \
# 172872                    Anywhere    via LinkedIn  Full-time and Part-time
# 129113                  London, UK    via LinkedIn                Full-time
# 168918                Columbus, OH      via Indeed                Full-time
# 777120                    Anywhere    via LinkedIn                      NaN
# 281295             Wrocław, Poland  via Talent.com                Full-time
# 654723               Madrid, Spain       via BeBee                Full-time
# 24589   Chennai, Tamil Nadu, India    via LinkedIn                Full-time
# 338410           Bangkok, Thailand     via JobThai                Full-time
# 299300               Madrid, Spain       via BeBee                Full-time
# 765415                 Atlanta, GA    via LinkedIn                Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 172872                True                 Denmark 2023-11-09 16:09:50
# 129113               False          United Kingdom 2023-06-19 08:32:11
# 168918               False                 Georgia 2023-03-08 16:12:07
# 777120                True                Malaysia 2023-01-31 05:21:44
# 281295               False                  Poland 2023-09-18 23:59:49
# 654723               False                   Spain 2023-12-10 10:41:23
# 24589                False                   India 2023-03-15 13:12:18
# 338410               False                Thailand 2023-01-04 08:47:22
# 299300               False                   Spain 2023-03-02 17:23:26
# 765415               False  Florida, United States 2023-01-31 01:06:26
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 172872                  False                 False         Denmark
# 129113                  False                 False  United Kingdom
# 168918                  False                 False   United States
# 777120                   True                 False        Malaysia
# 281295                   True                 False          Poland
# 654723                   True                 False           Spain
# 24589                   False                 False           India
# 338410                  False                 False        Thailand
# 299300                  False                 False           Spain
# 765415                  False                 False   United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 172872         NaN              NaN              NaN
# 129113         NaN              NaN              NaN
# 168918        year          95000.0              NaN
# 777120         NaN              NaN              NaN
# 281295         NaN              NaN              NaN
# 654723         NaN              NaN              NaN
# 24589          NaN              NaN              NaN
# 338410         NaN              NaN              NaN
# 299300         NaN              NaN              NaN
# 765415         NaN              NaN              NaN
#
#                                              company_name  \
# 172872                                            Agreena
# 129113                                     Cognify Search
# 168918                                  Devcare Solutions
# 777120                        Lavu Tech Solutions Sdn Bhd
# 281295                                       Michael Page
# 654723                                     Grupo PROEDUCA
# 24589                                             Magzter
# 338410  บริษัท ตงฮั้ว โฮลดิ้ง จำกัด (มหาชน) / Tong Hua...
# 299300                               Logicalis Group (DE)
# 765415                                   Focus Brands LLC
#
#                                                job_skills  \
# 172872              ['r', 'python', 'tidyverse', 'numpy']
# 129113  ['python', 'sql', 't-sql', 'sql server', 'azur...
# 168918  ['r', 'python', 'sas', 'sas', 'sql', 'db2', 's...
# 777120                     ['sql', 'azure', 'databricks']
# 281295                                                NaN
# 654723                  ['bigquery', 'looker', 'tableau']
# 24589                                  ['aws', 'tableau']
# 338410                                        ['graphql']
# 299300        ['python', 'java', 'scala', 'aws', 'azure']
# 765415  ['python', 'sql', 'gcp', 'snowflake', 'databri...
#
#                                           job_type_skills
# 172872  {'libraries': ['tidyverse', 'numpy'], 'program...
# 129113  {'analyst_tools': ['power bi', 'dax'], 'cloud'...
# 168918  {'analyst_tools': ['sas', 'microstrategy', 'ta...
# 777120  {'cloud': ['azure', 'databricks'], 'programmin...
# 281295                                                NaN
# 654723  {'analyst_tools': ['looker', 'tableau'], 'clou...
# 24589    {'analyst_tools': ['tableau'], 'cloud': ['aws']}
# 338410                         {'libraries': ['graphql']}
# 299300  {'cloud': ['aws', 'azure'], 'programming': ['p...
# 765415  {'analyst_tools': ['power bi'], 'cloud': ['gcp...
